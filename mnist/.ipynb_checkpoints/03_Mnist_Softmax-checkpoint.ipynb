# %% [markdown]
# # Mnist
#
#
# 教程： http://www.tensorfly.cn/tfdoc/tutorials/mnist_beginners.html
#
# 1. 修改 batch_size
# 2. 修改 learning rate
# 3. 增加迭代次数
# 4. 参数初始化的方式，比如改为随机初始化
# 5. 损失函数改为使用交叉熵

# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# 载入数据集，使用 one_hot 编码
mnist = input_data.read_data_sets("../dataset/mnist",one_hot=True)
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting ../dataset/mnist/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting ../dataset/mnist/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting ../dataset/mnist/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting ../dataset/mnist/t10k-labels-idx1-ubyte.gz

# %%
#每个批次的大小
batch_size = 100
#计算一共有多少个批次
n_batch = mnist.train.num_examples // batch_size

#定义两个placeholder
x = tf.placeholder(tf.float32,[None,784]) # 输入图片大小为28x28，其所有像素点可以看成784维的向量
y = tf.placeholder(tf.float32,[None,10]) # 输出将分成0~9共10类

#创建一个简单的神经网络
W = tf.Variable(tf.zeros([784,10]))
b = tf.Variable(tf.zeros([10]))
prediction = tf.nn.softmax(tf.matmul(x,W)+b) #输入信号转化而为概率值

#二次代价函数
loss = tf.reduce_mean(tf.square(y-prediction))
#使用梯度下降法
train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

#初始化变量
init = tf.global_variables_initializer()

#结果存放在一个布尔型列表中
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))#argmax返回一维张量中最大的值所在的位置
#求准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(21):
        for batch in range(n_batch):
            batch_xs,batch_ys =  mnist.train.next_batch(batch_size)
            sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys})
        
        acc = sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels})
        print("Iter " + str(epoch) + ",Testing Accuracy " + str(acc))
# Out:
# Iter 0,Testing Accuracy 0.8324
# Iter 1,Testing Accuracy 0.8703
# Iter 2,Testing Accuracy 0.8813
# Iter 3,Testing Accuracy 0.8883
# Iter 4,Testing Accuracy 0.8946
# Iter 5,Testing Accuracy 0.897
# Iter 6,Testing Accuracy 0.8992
# Iter 7,Testing Accuracy 0.9023
# Iter 8,Testing Accuracy 0.9034
# Iter 9,Testing Accuracy 0.9051
# Iter 10,Testing Accuracy 0.9066
# Iter 11,Testing Accuracy 0.9067
# Iter 12,Testing Accuracy 0.9084
# Iter 13,Testing Accuracy 0.9097
# Iter 14,Testing Accuracy 0.9098
# Iter 15,Testing Accuracy 0.911
# Iter 16,Testing Accuracy 0.9114
# Iter 17,Testing Accuracy 0.9131
# Iter 18,Testing Accuracy 0.9125
# Iter 19,Testing Accuracy 0.9139
# Iter 20,Testing Accuracy 0.9135

# %%
# 1. 修改batch_size

#每个批次的大小
batch_size = 50
#计算一共有多少个批次
n_batch = mnist.train.num_examples // batch_size

#定义两个placeholder
x = tf.placeholder(tf.float32,[None,784]) # 输入图片大小为28x28，其所有像素点可以看成784维的向量
y = tf.placeholder(tf.float32,[None,10]) # 输出将分成0~9共10类

#创建一个简单的神经网络
W = tf.Variable(tf.zeros([784,10]))
b = tf.Variable(tf.zeros([10]))
prediction = tf.nn.softmax(tf.matmul(x,W)+b) #输入信号转化而为概率值

#二次代价函数
loss = tf.reduce_mean(tf.square(y-prediction))
#使用梯度下降法
train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

#初始化变量
init = tf.global_variables_initializer()

#结果存放在一个布尔型列表中
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))#argmax返回一维张量中最大的值所在的位置
#求准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(21):
        for batch in range(n_batch):
            batch_xs,batch_ys =  mnist.train.next_batch(batch_size)
            sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys})
        
        acc = sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels})
        print("Iter " + str(epoch) + ",Testing Accuracy " + str(acc))
# Out:
# Iter 0,Testing Accuracy 0.8694
# Iter 1,Testing Accuracy 0.8877
# Iter 2,Testing Accuracy 0.8971
# Iter 3,Testing Accuracy 0.903
# Iter 4,Testing Accuracy 0.9054
# Iter 5,Testing Accuracy 0.9073
# Iter 6,Testing Accuracy 0.9096
# Iter 7,Testing Accuracy 0.9101
# Iter 8,Testing Accuracy 0.9128
# Iter 9,Testing Accuracy 0.9128
# Iter 10,Testing Accuracy 0.9151
# Iter 11,Testing Accuracy 0.9145
# Iter 12,Testing Accuracy 0.9171
# Iter 13,Testing Accuracy 0.9172
# Iter 14,Testing Accuracy 0.9175
# Iter 15,Testing Accuracy 0.918
# Iter 16,Testing Accuracy 0.9192
# Iter 17,Testing Accuracy 0.9185
# Iter 18,Testing Accuracy 0.9202
# Iter 19,Testing Accuracy 0.9197
# Iter 20,Testing Accuracy 0.9206

# %%
# 2. 修改学习率学习率
# 迭代次数少，学习率小一点也发挥不出效果

#每个批次的大小
batch_size = 100
#计算一共有多少个批次
n_batch = mnist.train.num_examples // batch_size

#定义两个placeholder
x = tf.placeholder(tf.float32,[None,784]) # 输入图片大小为28x28，其所有像素点可以看成784维的向量
y = tf.placeholder(tf.float32,[None,10]) # 输出将分成0~9共10类

#创建一个简单的神经网络
W = tf.Variable(tf.zeros([784,10]))
b = tf.Variable(tf.zeros([10]))
prediction = tf.nn.softmax(tf.matmul(x,W)+b) #输入信号转化而为概率值

#二次代价函数
loss = tf.reduce_mean(tf.square(y-prediction))
#使用梯度下降法
train_step = tf.train.GradientDescentOptimizer(0.01).minimize(loss)

#初始化变量
init = tf.global_variables_initializer()

#结果存放在一个布尔型列表中
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))#argmax返回一维张量中最大的值所在的位置
#求准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(21):
        for batch in range(n_batch):
            batch_xs,batch_ys =  mnist.train.next_batch(batch_size)
            sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys})
        
        acc = sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels})
        print("Iter " + str(epoch) + ",Testing Accuracy " + str(acc))
# Out:
# Iter 0,Testing Accuracy 0.6671
# Iter 1,Testing Accuracy 0.6502
# Iter 2,Testing Accuracy 0.6517
# Iter 3,Testing Accuracy 0.6702
# Iter 4,Testing Accuracy 0.6815
# Iter 5,Testing Accuracy 0.6883
# Iter 6,Testing Accuracy 0.7013
# Iter 7,Testing Accuracy 0.7169
# Iter 8,Testing Accuracy 0.7306
# Iter 9,Testing Accuracy 0.7452
# Iter 10,Testing Accuracy 0.7572
# Iter 11,Testing Accuracy 0.7659
# Iter 12,Testing Accuracy 0.7754
# Iter 13,Testing Accuracy 0.7823
# Iter 14,Testing Accuracy 0.7904
# Iter 15,Testing Accuracy 0.8006
# Iter 16,Testing Accuracy 0.8106
# Iter 17,Testing Accuracy 0.821
# Iter 18,Testing Accuracy 0.8269
# Iter 19,Testing Accuracy 0.8324
# Iter 20,Testing Accuracy 0.8373

# %%
# 增大迭代次数


#每个批次的大小
batch_size = 100
#计算一共有多少个批次
n_batch = mnist.train.num_examples // batch_size

#定义两个placeholder
x = tf.placeholder(tf.float32,[None,784]) # 输入图片大小为28x28，其所有像素点可以看成784维的向量
y = tf.placeholder(tf.float32,[None,10]) # 输出将分成0~9共10类

#创建一个简单的神经网络
W = tf.Variable(tf.zeros([784,10]))
b = tf.Variable(tf.zeros([10]))
prediction = tf.nn.softmax(tf.matmul(x,W)+b) #输入信号转化而为概率值

#二次代价函数
loss = tf.reduce_mean(tf.square(y-prediction))
#使用梯度下降法
train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

#初始化变量
init = tf.global_variables_initializer()

#结果存放在一个布尔型列表中
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))#argmax返回一维张量中最大的值所在的位置
#求准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(100):
        for batch in range(n_batch):
            batch_xs,batch_ys =  mnist.train.next_batch(batch_size)
            sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys})
        
        acc = sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels})
        print("Iter " + str(epoch) + ",Testing Accuracy " + str(acc))
# Out:
# Iter 0,Testing Accuracy 0.8325
# Iter 1,Testing Accuracy 0.871
# Iter 2,Testing Accuracy 0.8813
# Iter 3,Testing Accuracy 0.8876
# Iter 4,Testing Accuracy 0.8937
# Iter 5,Testing Accuracy 0.8977
# Iter 6,Testing Accuracy 0.8991
# Iter 7,Testing Accuracy 0.9016
# Iter 8,Testing Accuracy 0.9029
# Iter 9,Testing Accuracy 0.9052
# Iter 10,Testing Accuracy 0.9069
# Iter 11,Testing Accuracy 0.9076
# Iter 12,Testing Accuracy 0.9087
# Iter 13,Testing Accuracy 0.9098
# Iter 14,Testing Accuracy 0.9095
# Iter 15,Testing Accuracy 0.9102
# Iter 16,Testing Accuracy 0.9125
# Iter 17,Testing Accuracy 0.9128
# Iter 18,Testing Accuracy 0.9125
# Iter 19,Testing Accuracy 0.9138
# Iter 20,Testing Accuracy 0.9139
# Iter 21,Testing Accuracy 0.915
# Iter 22,Testing Accuracy 0.9157
# Iter 23,Testing Accuracy 0.9151
# Iter 24,Testing Accuracy 0.9159
# Iter 25,Testing Accuracy 0.9167
# Iter 26,Testing Accuracy 0.9172
# Iter 27,Testing Accuracy 0.9172
# Iter 28,Testing Accuracy 0.9174
# Iter 29,Testing Accuracy 0.918
# Iter 30,Testing Accuracy 0.9177
# Iter 31,Testing Accuracy 0.9182
# Iter 32,Testing Accuracy 0.9182
# Iter 33,Testing Accuracy 0.9185
# Iter 34,Testing Accuracy 0.9186
# Iter 35,Testing Accuracy 0.9182
# Iter 36,Testing Accuracy 0.9191
# Iter 37,Testing Accuracy 0.9188
# Iter 38,Testing Accuracy 0.9191
# Iter 39,Testing Accuracy 0.9195
# Iter 40,Testing Accuracy 0.9195
# Iter 41,Testing Accuracy 0.9199
# Iter 42,Testing Accuracy 0.9207
# Iter 43,Testing Accuracy 0.9204
# Iter 44,Testing Accuracy 0.9205
# Iter 45,Testing Accuracy 0.9207
# Iter 46,Testing Accuracy 0.9207
# Iter 47,Testing Accuracy 0.9212
# Iter 48,Testing Accuracy 0.921
# Iter 49,Testing Accuracy 0.9215
# Iter 50,Testing Accuracy 0.9213
# Iter 51,Testing Accuracy 0.9217
# Iter 52,Testing Accuracy 0.9214
# Iter 53,Testing Accuracy 0.9219
# Iter 54,Testing Accuracy 0.9218
# Iter 55,Testing Accuracy 0.9222
# Iter 56,Testing Accuracy 0.9218
# Iter 57,Testing Accuracy 0.9221
# Iter 58,Testing Accuracy 0.9222
# Iter 59,Testing Accuracy 0.9222
# Iter 60,Testing Accuracy 0.9227
# Iter 61,Testing Accuracy 0.923
# Iter 62,Testing Accuracy 0.923
# Iter 63,Testing Accuracy 0.9233
# Iter 64,Testing Accuracy 0.9235
# Iter 65,Testing Accuracy 0.9237
# Iter 66,Testing Accuracy 0.9234
# Iter 67,Testing Accuracy 0.9236
# Iter 68,Testing Accuracy 0.924
# Iter 69,Testing Accuracy 0.9239
# Iter 70,Testing Accuracy 0.9243
# Iter 71,Testing Accuracy 0.9243
# Iter 72,Testing Accuracy 0.9245
# Iter 73,Testing Accuracy 0.9248
# Iter 74,Testing Accuracy 0.9246
# Iter 75,Testing Accuracy 0.9242
# Iter 76,Testing Accuracy 0.9246
# Iter 77,Testing Accuracy 0.9245
# Iter 78,Testing Accuracy 0.9251
# Iter 79,Testing Accuracy 0.9245
# Iter 80,Testing Accuracy 0.9248
# Iter 81,Testing Accuracy 0.9245
# Iter 82,Testing Accuracy 0.9245
# Iter 83,Testing Accuracy 0.9258
# Iter 84,Testing Accuracy 0.9252
# Iter 85,Testing Accuracy 0.9249
# Iter 86,Testing Accuracy 0.925
# Iter 87,Testing Accuracy 0.9247
# Iter 88,Testing Accuracy 0.9255
# Iter 89,Testing Accuracy 0.9256
# Iter 90,Testing Accuracy 0.9264
# Iter 91,Testing Accuracy 0.9256
# Iter 92,Testing Accuracy 0.926
# Iter 93,Testing Accuracy 0.9251
# Iter 94,Testing Accuracy 0.9255
# Iter 95,Testing Accuracy 0.9263
# Iter 96,Testing Accuracy 0.926
# Iter 97,Testing Accuracy 0.9259
# Iter 98,Testing Accuracy 0.9262
# Iter 99,Testing Accuracy 0.9263

# %%
# 权因子随机初始化


#每个批次的大小
batch_size = 100
#计算一共有多少个批次
n_batch = mnist.train.num_examples // batch_size

#定义两个placeholder
x = tf.placeholder(tf.float32,[None,784]) # 输入图片大小为28x28，其所有像素点可以看成784维的向量
y = tf.placeholder(tf.float32,[None,10]) # 输出将分成0~9共10类

#创建一个简单的神经网络
weight_initer = tf.truncated_normal_initializer(mean=0.0, stddev=0.01)
W = tf.get_variable("W", shape=([784, 10]), initializer=weight_initer)
# W = tf.Variable(tf.zeros([784,10]))
b = tf.Variable(tf.zeros([10]))
prediction = tf.nn.softmax(tf.matmul(x,W)+b) #输入信号转化而为概率值

#二次代价函数
loss = tf.reduce_mean(tf.square(y-prediction))
#使用梯度下降法
train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

#初始化变量
init = tf.global_variables_initializer()

#结果存放在一个布尔型列表中
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))#argmax返回一维张量中最大的值所在的位置
#求准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(100):
        for batch in range(n_batch):
            batch_xs,batch_ys =  mnist.train.next_batch(batch_size)
            sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys})
        
        acc = sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels})
        print("Iter " + str(epoch) + ",Testing Accuracy " + str(acc))
# Out:
# Iter 0,Testing Accuracy 0.8263
# Iter 1,Testing Accuracy 0.8699
# Iter 2,Testing Accuracy 0.8815
# Iter 3,Testing Accuracy 0.8876
# Iter 4,Testing Accuracy 0.8939
# Iter 5,Testing Accuracy 0.8972
# Iter 6,Testing Accuracy 0.8993
# Iter 7,Testing Accuracy 0.9014
# Iter 8,Testing Accuracy 0.9033
# Iter 9,Testing Accuracy 0.9049
# Iter 10,Testing Accuracy 0.906
# Iter 11,Testing Accuracy 0.9081
# Iter 12,Testing Accuracy 0.9089
# Iter 13,Testing Accuracy 0.9087
# Iter 14,Testing Accuracy 0.9095
# Iter 15,Testing Accuracy 0.911
# Iter 16,Testing Accuracy 0.9121
# Iter 17,Testing Accuracy 0.9127
# Iter 18,Testing Accuracy 0.9131
# Iter 19,Testing Accuracy 0.9134
# Iter 20,Testing Accuracy 0.9141
# Iter 21,Testing Accuracy 0.9144
# Iter 22,Testing Accuracy 0.9145
# Iter 23,Testing Accuracy 0.9152
# Iter 24,Testing Accuracy 0.9158
# Iter 25,Testing Accuracy 0.9161
# Iter 26,Testing Accuracy 0.9164
# Iter 27,Testing Accuracy 0.9177
# Iter 28,Testing Accuracy 0.9172
# Iter 29,Testing Accuracy 0.9172
# Iter 30,Testing Accuracy 0.9178
# Iter 31,Testing Accuracy 0.9183
# Iter 32,Testing Accuracy 0.9184
# Iter 33,Testing Accuracy 0.9185
# Iter 34,Testing Accuracy 0.9189
# Iter 35,Testing Accuracy 0.9189
# Iter 36,Testing Accuracy 0.919
# Iter 37,Testing Accuracy 0.9193
# Iter 38,Testing Accuracy 0.9195
# Iter 39,Testing Accuracy 0.92
# Iter 40,Testing Accuracy 0.9189
# Iter 41,Testing Accuracy 0.9198
# Iter 42,Testing Accuracy 0.9196
# Iter 43,Testing Accuracy 0.9208
# Iter 44,Testing Accuracy 0.92
# Iter 45,Testing Accuracy 0.9205
# Iter 46,Testing Accuracy 0.9204
# Iter 47,Testing Accuracy 0.9208
# Iter 48,Testing Accuracy 0.9208
# Iter 49,Testing Accuracy 0.9213
# Iter 50,Testing Accuracy 0.9215
# Iter 51,Testing Accuracy 0.9216
# Iter 52,Testing Accuracy 0.9217
# Iter 53,Testing Accuracy 0.9222
# Iter 54,Testing Accuracy 0.9218
# Iter 55,Testing Accuracy 0.9221
# Iter 56,Testing Accuracy 0.9221
# Iter 57,Testing Accuracy 0.9218
# Iter 58,Testing Accuracy 0.9223
# Iter 59,Testing Accuracy 0.9225
# Iter 60,Testing Accuracy 0.923
# Iter 61,Testing Accuracy 0.923
# Iter 62,Testing Accuracy 0.923
# Iter 63,Testing Accuracy 0.9228
# Iter 64,Testing Accuracy 0.9233
# Iter 65,Testing Accuracy 0.9234
# Iter 66,Testing Accuracy 0.9238
# Iter 67,Testing Accuracy 0.9233
# Iter 68,Testing Accuracy 0.9237
# Iter 69,Testing Accuracy 0.924
# Iter 70,Testing Accuracy 0.9241
# Iter 71,Testing Accuracy 0.9246
# Iter 72,Testing Accuracy 0.9238
# Iter 73,Testing Accuracy 0.9241
# Iter 74,Testing Accuracy 0.9243
# Iter 75,Testing Accuracy 0.9241
# Iter 76,Testing Accuracy 0.924
# Iter 77,Testing Accuracy 0.9244
# Iter 78,Testing Accuracy 0.9245
# Iter 79,Testing Accuracy 0.9248
# Iter 80,Testing Accuracy 0.9236
# Iter 81,Testing Accuracy 0.9244
# Iter 82,Testing Accuracy 0.9249
# Iter 83,Testing Accuracy 0.9247
# Iter 84,Testing Accuracy 0.9249
# Iter 85,Testing Accuracy 0.9248
# Iter 86,Testing Accuracy 0.9251
# Iter 87,Testing Accuracy 0.9245
# Iter 88,Testing Accuracy 0.9255
# Iter 89,Testing Accuracy 0.9252
# Iter 90,Testing Accuracy 0.9249
# Iter 91,Testing Accuracy 0.9255
# Iter 92,Testing Accuracy 0.9252
# Iter 93,Testing Accuracy 0.9255
# Iter 94,Testing Accuracy 0.926
# Iter 95,Testing Accuracy 0.926
# Iter 96,Testing Accuracy 0.9257
# Iter 97,Testing Accuracy 0.9258
# Iter 98,Testing Accuracy 0.926
# Iter 99,Testing Accuracy 0.9256

# %%
# 损失函数使用交叉熵


#每个批次的大小
batch_size = 100
#计算一共有多少个批次
n_batch = mnist.train.num_examples // batch_size

#定义两个placeholder
x = tf.placeholder(tf.float32,[None,784]) # 输入图片大小为28x28，其所有像素点可以看成784维的向量
y = tf.placeholder(tf.float32,[None,10]) # 输出将分成0~9共10类

#创建一个简单的神经网络
W = tf.Variable(tf.zeros([784,10]))
b = tf.Variable(tf.zeros([10]))
prediction = tf.nn.softmax(tf.matmul(x,W)+b) #输入信号转化而为概率值

#二次代价函数
# loss = tf.reduce_mean(tf.square(y-prediction))
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=prediction))
#使用梯度下降法
train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

#初始化变量
init = tf.global_variables_initializer()

#结果存放在一个布尔型列表中
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))#argmax返回一维张量中最大的值所在的位置
#求准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(100):
        for batch in range(n_batch):
            batch_xs,batch_ys =  mnist.train.next_batch(batch_size)
            sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys})
        
        acc = sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels})
        print("Iter " + str(epoch) + ",Testing Accuracy " + str(acc))
# Out:
# Iter 0,Testing Accuracy 0.8231
# Iter 1,Testing Accuracy 0.8882
# Iter 2,Testing Accuracy 0.9009
# Iter 3,Testing Accuracy 0.905
# Iter 4,Testing Accuracy 0.907
# Iter 5,Testing Accuracy 0.9099
# Iter 6,Testing Accuracy 0.912
# Iter 7,Testing Accuracy 0.9133
# Iter 8,Testing Accuracy 0.9155
# Iter 9,Testing Accuracy 0.915
# Iter 10,Testing Accuracy 0.9169
# Iter 11,Testing Accuracy 0.9191
# Iter 12,Testing Accuracy 0.9197
# Iter 13,Testing Accuracy 0.919
# Iter 14,Testing Accuracy 0.9193
# Iter 15,Testing Accuracy 0.9207
# Iter 16,Testing Accuracy 0.9195
# Iter 17,Testing Accuracy 0.9206
# Iter 18,Testing Accuracy 0.9209
# Iter 19,Testing Accuracy 0.9212
# Iter 20,Testing Accuracy 0.9215
# Iter 21,Testing Accuracy 0.9217
# Iter 22,Testing Accuracy 0.9222
# Iter 23,Testing Accuracy 0.9223
# Iter 24,Testing Accuracy 0.9234
# Iter 25,Testing Accuracy 0.9229
# Iter 26,Testing Accuracy 0.9222
# Iter 27,Testing Accuracy 0.9231
# Iter 28,Testing Accuracy 0.9233
# Iter 29,Testing Accuracy 0.9238
# Iter 30,Testing Accuracy 0.9238
# Iter 31,Testing Accuracy 0.9237
# Iter 32,Testing Accuracy 0.9252
# Iter 33,Testing Accuracy 0.9249
# Iter 34,Testing Accuracy 0.9244
# Iter 35,Testing Accuracy 0.9239
# Iter 36,Testing Accuracy 0.9248
# Iter 37,Testing Accuracy 0.9258
# Iter 38,Testing Accuracy 0.9256
# Iter 39,Testing Accuracy 0.9258
# Iter 40,Testing Accuracy 0.9261
# Iter 41,Testing Accuracy 0.9253
# Iter 42,Testing Accuracy 0.9254
# Iter 43,Testing Accuracy 0.9258
# Iter 44,Testing Accuracy 0.9261
# Iter 45,Testing Accuracy 0.9267
# Iter 46,Testing Accuracy 0.9265
# Iter 47,Testing Accuracy 0.9269
# Iter 48,Testing Accuracy 0.9261
# Iter 49,Testing Accuracy 0.9266
# Iter 50,Testing Accuracy 0.9267
# Iter 51,Testing Accuracy 0.9268
# Iter 52,Testing Accuracy 0.9272
# Iter 53,Testing Accuracy 0.928
# Iter 54,Testing Accuracy 0.927
# Iter 55,Testing Accuracy 0.9276
# Iter 56,Testing Accuracy 0.9278
# Iter 57,Testing Accuracy 0.927
# Iter 58,Testing Accuracy 0.9275
# Iter 59,Testing Accuracy 0.9283
# Iter 60,Testing Accuracy 0.9279
# Iter 61,Testing Accuracy 0.9281
# Iter 62,Testing Accuracy 0.9273
# Iter 63,Testing Accuracy 0.9283
# Iter 64,Testing Accuracy 0.9276
# Iter 65,Testing Accuracy 0.9273
# Iter 66,Testing Accuracy 0.9275
# Iter 67,Testing Accuracy 0.928
# Iter 68,Testing Accuracy 0.928
# Iter 69,Testing Accuracy 0.9284
# Iter 70,Testing Accuracy 0.9287
# Iter 71,Testing Accuracy 0.9281
# Iter 72,Testing Accuracy 0.9286
# Iter 73,Testing Accuracy 0.9288
# Iter 74,Testing Accuracy 0.9277
# Iter 75,Testing Accuracy 0.9282
# Iter 76,Testing Accuracy 0.9284
# Iter 77,Testing Accuracy 0.9287
# Iter 78,Testing Accuracy 0.928
# Iter 79,Testing Accuracy 0.9289
# Iter 80,Testing Accuracy 0.9276
# Iter 81,Testing Accuracy 0.9282
# Iter 82,Testing Accuracy 0.9282
# Iter 83,Testing Accuracy 0.9276
# Iter 84,Testing Accuracy 0.9286
# Iter 85,Testing Accuracy 0.9281
# Iter 86,Testing Accuracy 0.9284
# Iter 87,Testing Accuracy 0.9283
# Iter 88,Testing Accuracy 0.9284
# Iter 89,Testing Accuracy 0.9284
# Iter 90,Testing Accuracy 0.9284
# Iter 91,Testing Accuracy 0.9285
# Iter 92,Testing Accuracy 0.9285
# Iter 93,Testing Accuracy 0.9285
# Iter 94,Testing Accuracy 0.9288
# Iter 95,Testing Accuracy 0.9283
# Iter 96,Testing Accuracy 0.9284
# Iter 97,Testing Accuracy 0.9286
# Iter 98,Testing Accuracy 0.9295
# Iter 99,Testing Accuracy 0.9287
